# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
# %matplotlib inline

# %%
n_pts = 500
np.random.seed(0)
Xa = np.array([np.random.normal(13, 2, n_pts),
               np.random.normal(12, 2, n_pts)]).T
Xb = np.array([np.random.normal(8, 2, n_pts),
               np.random.normal(6, 2, n_pts)]).T

X = np.vstack((Xa, Xb))
Y = np.matrix(np.append(np.zeros(n_pts), np.ones(n_pts))).T

plt.scatter(X[:n_pts,0], X[:n_pts,1])
plt.scatter(X[n_pts:,0], X[n_pts:,1])

# %%
model = tf.keras.models.Sequential()
model.add(
    tf.keras.layers.Dense(units = 1, input_shape = (2,), activation = 'sigmoid')
)
adam = tf.keras.optimizers.Adam(lr=0.1)
model.compile(adam, loss = 'binary_crossentropy', metrics=['accuracy'])
h = model.fit(x=X, y=Y, verbose=1, batch_size=50, epochs = 20, shuffle = 'true')
# Out:
# Train on 1000 samples
# Epoch 1/20
# 1000/1000 [==============================] - 1s 710us/sample - loss: 0.9147 - accuracy: 0.5200
# Epoch 2/20
# 1000/1000 [==============================] - 0s 63us/sample - loss: 0.5629 - accuracy: 0.6780
# Epoch 3/20
# 1000/1000 [==============================] - 0s 50us/sample - loss: 0.4661 - accuracy: 0.8030
# Epoch 4/20
# 1000/1000 [==============================] - 0s 67us/sample - loss: 0.3850 - accuracy: 0.8820
# Epoch 5/20
# 1000/1000 [==============================] - 0s 99us/sample - loss: 0.3341 - accuracy: 0.9180
# Epoch 6/20
# 1000/1000 [==============================] - 0s 77us/sample - loss: 0.2959 - accuracy: 0.9330
# Epoch 7/20
# 1000/1000 [==============================] - 0s 46us/sample - loss: 0.2646 - accuracy: 0.9400
# Epoch 8/20
# 1000/1000 [==============================] - 0s 54us/sample - loss: 0.2418 - accuracy: 0.9440
# Epoch 9/20
# 1000/1000 [==============================] - 0s 47us/sample - loss: 0.2176 - accuracy: 0.9570
# Epoch 10/20
# 1000/1000 [==============================] - 0s 62us/sample - loss: 0.2003 - accuracy: 0.9620
# Epoch 11/20
# 1000/1000 [==============================] - 0s 66us/sample - loss: 0.1857 - accuracy: 0.9670
# Epoch 12/20
# 1000/1000 [==============================] - 0s 58us/sample - loss: 0.1776 - accuracy: 0.9680
# Epoch 13/20
# 1000/1000 [==============================] - 0s 67us/sample - loss: 0.1644 - accuracy: 0.9710
# Epoch 14/20
# 1000/1000 [==============================] - 0s 62us/sample - loss: 0.1569 - accuracy: 0.9740
# Epoch 15/20
# 1000/1000 [==============================] - 0s 50us/sample - loss: 0.1478 - accuracy: 0.9740
# Epoch 16/20
# 1000/1000 [==============================] - 0s 59us/sample - loss: 0.1418 - accuracy: 0.9710
# Epoch 17/20
# 1000/1000 [==============================] - 0s 49us/sample - loss: 0.1360 - accuracy: 0.9710
# Epoch 18/20
# 1000/1000 [==============================] - 0s 62us/sample - loss: 0.1315 - accuracy: 0.9690
# Epoch 19/20
# 1000/1000 [==============================] - 0s 46us/sample - loss: 0.1265 - accuracy: 0.9760
# Epoch 20/20
# 1000/1000 [==============================] - 0s 55us/sample - loss: 0.1283 - accuracy: 0.9720

# %%
plt.plot(h.history['accuracy'])
plt.title('accuracy')
plt.xlabel('epoch')
plt.legend('accuracy')

# %%
plt.plot(h.history['loss'])
plt.title('loss')
plt.xlabel('epoch')
plt.legend(['loss'])

# %%
def plot_decision_boundary(X, y, model):
    x_span = np.linspace(min(X[:,0]) - 1, max(X[:,0]) + 1)
    y_span = np.linspace(min(X[:,1]) - 1, max(X[:,1]) + 1)
    xx, yy = np.meshgrid(x_span, y_span)
    xx_, yy_ = xx.ravel(), yy.ravel()
    grid = np.c_[xx_, yy_]
    pred_func = model.predict(grid)
    z = pred_func.reshape(xx.shape)
    plt.contourf(xx, yy, z)

# %%
plot_decision_boundary(X, y, model)
plt.scatter(X[:n_pts,0], X[:n_pts,1])
plt.scatter(X[n_pts:,0], X[n_pts:,1])

# %%
plot_decision_boundary(X, y, model)
plt.scatter(X[:n_pts,0], X[:n_pts,1])
plt.scatter(X[n_pts:,0], X[n_pts:,1])

x1 = 7.5
x2 = 5

point = np.array([[x1,x2]])
prediction = model.predict(point)
plt.plot([x1], [x2], marker='o', markersize=15, color='b')
print("Prediction is:", prediction)
# Out:
# Prediction is: [[0.9823484]]
